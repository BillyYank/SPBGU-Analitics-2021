# %% [markdown]
# Эти задачки надо решать без помощи циклов, только средствами numpy

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy
from tqdm import tqdm
import pandas as pd

# %matplotlib inline
sns.set()

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1) Создать массив 10x10 со случайными значениями, найти минимум и максимум

# %%
N = np.random.rand(10, 10)
Min = np.min(N)
Max = np.max(N)
Max, Min
# Out:
# (0.9948970026645466, 0.0076769422245756)

# %% [markdown]
# 2) Заменить максимальный элемент на ноль в массиве

# %%
massiv = np.random.uniform(size=100)

# %%
massiv
# Out:
# array([0.33057791, 0.33232609, 0.40417014, 0.47817207, 0.90946497,
#        0.96531879, 0.16681117, 0.07003634, 0.60668298, 0.9155287 ,
#        0.63133673, 0.27145763, 0.24113349, 0.25954232, 0.76290589,
#        0.2834079 , 0.65238959, 0.07161103, 0.15435375, 0.00314922,
#        0.01108201, 0.56656718, 0.74287242, 0.73577839, 0.91799482,
#        0.07991863, 0.81118429, 0.37891309, 0.90408814, 0.27527044,
#        0.6953654 , 0.81045237, 0.98168303, 0.65441122, 0.18359249,
#        0.89935929, 0.65117881, 0.15259738, 0.60738695, 0.91614032,
#        0.75822084, 0.90848704, 0.52780414, 0.4611329 , 0.20012725,
#        0.89774993, 0.68603059, 0.16064945, 0.2374197 , 0.54835878,
#        0.13760734, 0.61127699, 0.38418162, 0.13379952, 0.58402256,
#        0.97320607, 0.9123929 , 0.78568369, 0.60446192, 0.70058191,
#        0.15413861, 0.22619157, 0.96907111, 0.49555939, 0.69728868,
#        0.1563528 , 0.8714255 , 0.16156434, 0.5558926 , 0.96208882,
#        0.05915723, 0.37705926, 0.02172545, 0.76801369, 0.41263553,
#        0.99722737, 0.27324523, 0.47727046, 0.9752685 , 0.1255444 ,
#        0.3281066 , 0.74854316, 0.44165229, 0.51924127, 0.61225361,
#        0.64633302, 0.36893595, 0.35402857, 0.07150022, 0.05470264,
#        0.54330217, 0.81619563, 0.65845545, 0.55482473, 0.16587077,
#        0.2142694 , 0.59701638, 0.83371474, 0.4167506 , 0.94073525])

# %%
massiv.max()
# Out:
# 0.9972273682021694

# %%
Max = np.max(massiv)
i = np.where(massiv == Max)
massiv[i] = 0
massiv
# Out:
# array([0.33057791, 0.33232609, 0.40417014, 0.47817207, 0.90946497,
#        0.96531879, 0.16681117, 0.07003634, 0.60668298, 0.9155287 ,
#        0.63133673, 0.27145763, 0.24113349, 0.25954232, 0.76290589,
#        0.2834079 , 0.65238959, 0.07161103, 0.15435375, 0.00314922,
#        0.01108201, 0.56656718, 0.74287242, 0.73577839, 0.91799482,
#        0.07991863, 0.81118429, 0.37891309, 0.90408814, 0.27527044,
#        0.6953654 , 0.81045237, 0.        , 0.65441122, 0.18359249,
#        0.89935929, 0.65117881, 0.15259738, 0.60738695, 0.91614032,
#        0.75822084, 0.90848704, 0.52780414, 0.4611329 , 0.20012725,
#        0.89774993, 0.68603059, 0.16064945, 0.2374197 , 0.54835878,
#        0.13760734, 0.61127699, 0.38418162, 0.13379952, 0.58402256,
#        0.        , 0.9123929 , 0.78568369, 0.60446192, 0.70058191,
#        0.15413861, 0.22619157, 0.        , 0.49555939, 0.69728868,
#        0.1563528 , 0.8714255 , 0.16156434, 0.5558926 , 0.96208882,
#        0.05915723, 0.37705926, 0.02172545, 0.76801369, 0.41263553,
#        0.        , 0.27324523, 0.47727046, 0.        , 0.1255444 ,
#        0.3281066 , 0.74854316, 0.44165229, 0.51924127, 0.61225361,
#        0.64633302, 0.36893595, 0.35402857, 0.07150022, 0.05470264,
#        0.54330217, 0.81619563, 0.65845545, 0.55482473, 0.16587077,
#        0.2142694 , 0.59701638, 0.83371474, 0.4167506 , 0.94073525])

# %% [markdown]
# 3) Найти след произведения двух матриц (сумму диагональных элементов)

# %%
A = np.random.normal(size=(10, 5))
B = np.random.normal(size=(5, 10))

# %% [markdown]
# Далее можно использовать циклы, но по возможности лучше без них

# %% [markdown]
# 4) Построить графики
#
#     a) Нормального распределения ( с параметрами 0, 1)
#     б) Распределение Стьюдента ( n = 2, например )

# %% [markdown]
# 5) Возьмите датасет из самой первой домашки (heart.csv), посчитайте попарные корреляции признаков (нужные функции есть в numpy, но удобнее использовать pandas для этих целей, там есть метод .corr у датафрейма)
#
#     Затем постройте heatmap полученной таблицы, heatmap есть в seaborn: https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# 6) Есть много критериев проверки стат гипотезы о равенстве распределения данному. Давайте возьмем два из них
#     1) хи-квадрат: https://ru.wikipedia.org/wiki/Критерий_согласия_Пирсона
#     2) Колмогоров-Смирнов: https://ru.wikipedia.org/wiki/Критерий_согласия_Колмогорова
#
#    Интересно, как зависит p-value от размера выборки. Постройте две кривые: по оси x - размер выборки, по y - p-value, которое выдает соответствующий критерий. В качестве тестовых данных давайте генерить выборки из равномерного распределения на [0, 1]

# %%
p_values = []
point_numbers = list(range(10, 1000, 100))
for N in point_numbers:
    """
    вычисляю p_value для N
    """
    p_values.append(p_value)

# %%
plt.plot(point_numbers, p_values)
