# %% [markdown]
# Найдите список всех самолетов, находящихся сейчас в воздухе. (Имеется в виду на момент выполнения домашки)
#
# Возможно вам поможет это: https://aviationstack.com/documentation

# %%
api_key = 'b29c58e1180d4641a0fc30fbf862c203'

# %%
import requests
import json
import pandas as pd

# %%
url = 'http://api.aviationstack.com/v1/flights'
planes = json.loads(requests.get(url, params={
    'access_key': api_key,
    'flight_status': 'active'
}).content)

# %%
flights_now = pd.json_normalize(planes['data'])

# %%
flights_now
# Out:
#    flight_date flight_status  aircraft  live  \
# 0   2021-11-30        active       NaN   NaN
# 1   2021-11-30        active       NaN   NaN
# 2   2021-11-30        active       NaN   NaN
# 3   2021-11-30        active       NaN   NaN
# 4   2021-11-29        active       NaN   NaN
# ..         ...           ...       ...   ...
# 95  2021-11-29        active       NaN   NaN
# 96  2021-11-29        active       NaN   NaN
# 97  2021-11-29        active       NaN   NaN
# 98  2021-11-29        active       NaN   NaN
# 99  2021-11-29        active       NaN   NaN
#
#                       departure.airport   departure.timezone departure.iata  \
# 0                           Tullamarine  Australia/Melbourne            MEL
# 1                           Tullamarine  Australia/Melbourne            MEL
# 2                           Tullamarine  Australia/Melbourne            MEL
# 3                           Tullamarine  Australia/Melbourne            MEL
# 4                          Novy Urengoy   Asia/Yekaterinburg            NUX
# ..                                  ...                  ...            ...
# 95  Nanjing Lukou International Airport        Asia/Shanghai            NKG
# 96  Nanjing Lukou International Airport        Asia/Shanghai            NKG
# 97  Nanjing Lukou International Airport        Asia/Shanghai            NKG
# 98  Nanjing Lukou International Airport        Asia/Shanghai            NKG
# 99  Nanjing Lukou International Airport        Asia/Shanghai            NKG
#
#    departure.icao departure.terminal departure.gate  ...  aircraft.icao  \
# 0            YMML                  2              9  ...            NaN
# 1            YMML                  2              9  ...            NaN
# 2            YMML                  2              9  ...            NaN
# 3            YMML                  2              9  ...            NaN
# 4            USMU               None           None  ...            NaN
# ..            ...                ...            ...  ...            ...
# 95           ZSNJ                  2             21  ...            NaN
# 96           ZSNJ                  2             21  ...            NaN
# 97           ZSNJ                  1            125  ...            NaN
# 98           ZSNJ                  1            125  ...            NaN
# 99           ZSNJ                  2             18  ...           B738
#
#    aircraft.icao24               live.updated live.latitude live.longitude  \
# 0              NaN                        NaN           NaN            NaN
# 1              NaN                        NaN           NaN            NaN
# 2              NaN                        NaN           NaN            NaN
# 3              NaN                        NaN           NaN            NaN
# 4              NaN                        NaN           NaN            NaN
# ..             ...                        ...           ...            ...
# 95             NaN                        NaN           NaN            NaN
# 96             NaN                        NaN           NaN            NaN
# 97             NaN                        NaN           NaN            NaN
# 98             NaN                        NaN           NaN            NaN
# 99          780476  2021-11-29T07:56:09+00:00         30.75         110.92
#
#    live.altitude live.direction live.speed_horizontal live.speed_vertical  \
# 0            NaN            NaN                   NaN                 NaN
# 1            NaN            NaN                   NaN                 NaN
# 2            NaN            NaN                   NaN                 NaN
# 3            NaN            NaN                   NaN                 NaN
# 4            NaN            NaN                   NaN                 NaN
# ..           ...            ...                   ...                 ...
# 95           NaN            NaN                   NaN                 NaN
# 96           NaN            NaN                   NaN                 NaN
# 97           NaN            NaN                   NaN                 NaN
# 98           NaN            NaN                   NaN                 NaN
# 99       9174.48          272.0               650.052                 0.0
#
#    live.is_ground
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 95            NaN
# 96            NaN
# 97            NaN
# 98            NaN
# 99          False
#
# [100 rows x 54 columns]
