# %% [markdown]
# Найдите список всех самолетов, находящихся сейчас в воздухе. (Имеется в виду на момент выполнения домашки)
#
# Возможно вам поможет это: https://aviationstack.com/documentation

# %%
api_key = 'c2553a65eec9a0b1cccdbf41984d3b4e'

# %%
import requests
import json
import pandas as pd

# %%
url = 'http://api.aviationstack.com/v1/flights'
planes = json.loads(requests.get(url, params={
    'access_key': api_key,
    'flight_status': 'active'
}).content)

# %%
flights = pd.json_normalize(planes['data'])
flights
# Out:
#    flight_date flight_status             departure.airport  \
# 0   2021-12-01        active             Kozhikode Airport
# 1   2021-12-01        active                      Shenzhen
# 2   2021-12-01        active      Townsville International
# 3   2021-12-01        active  Soekarno-Hatta International
# 4   2021-12-01        active                Port Macquarie
# ..         ...           ...                           ...
# 95  2021-12-01        active                        Mackay
# 96  2021-12-01        active                        Mackay
# 97  2021-12-01        active                        Mackay
# 98  2021-12-01        active      Wellington International
# 99  2021-12-01        active      Wellington International
#
#     departure.timezone departure.iata departure.icao departure.terminal  \
# 0         Asia/Kolkata            CCJ           VOCL               None
# 1        Asia/Shanghai            SZX           ZGSZ               None
# 2   Australia/Brisbane            TSV           YBTL               None
# 3         Asia/Jakarta            CGK           WIII                  2
# 4     Australia/Sydney            PQQ           YPMQ               None
# ..                 ...            ...            ...                ...
# 95  Australia/Brisbane            MKY           YBMK               None
# 96  Australia/Brisbane            MKY           YBMK               None
# 97  Australia/Brisbane            MKY           YBMK               None
# 98    Pacific/Auckland            WLG           NZWN               None
# 99    Pacific/Auckland            WLG           NZWN               None
#
#    departure.gate  departure.delay        departure.scheduled  ...  \
# 0            None              7.0  2021-12-01T00:35:00+00:00  ...
# 1            None             13.0  2021-12-01T03:25:00+00:00  ...
# 2               4             13.0  2021-12-01T06:00:00+00:00  ...
# 3             C22             16.0  2021-12-01T02:30:00+00:00  ...
# 4            None              2.0  2021-12-01T06:40:00+00:00  ...
# ..            ...              ...                        ...  ...
# 95              4              NaN  2021-12-01T06:30:00+00:00  ...
# 96              4              NaN  2021-12-01T06:30:00+00:00  ...
# 97              4              NaN  2021-12-01T06:30:00+00:00  ...
# 98             17             14.0  2021-12-01T08:50:00+00:00  ...
# 99             17             14.0  2021-12-01T08:50:00+00:00  ...
#
#    live.speed_vertical live.is_ground aircraft live  \
# 0                  0.0          False      NaN  NaN
# 1                  NaN            NaN      NaN  NaN
# 2                  NaN            NaN      NaN  NaN
# 3                  NaN            NaN      NaN  NaN
# 4                  NaN            NaN      NaN  NaN
# ..                 ...            ...      ...  ...
# 95                 NaN            NaN      NaN  NaN
# 96                 NaN            NaN      NaN  NaN
# 97                 NaN            NaN      NaN  NaN
# 98                 NaN            NaN      NaN  NaN
# 99                 NaN            NaN      NaN  NaN
#
#    flight.codeshared.airline_name flight.codeshared.airline_iata  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# ..                            ...                            ...
# 95               virgin australia                             va
# 96               virgin australia                             va
# 97               virgin australia                             va
# 98                air new zealand                             nz
# 99                air new zealand                             nz
#
#    flight.codeshared.airline_icao flight.codeshared.flight_number  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# ..                            ...                             ...
# 95                            voz                             600
# 96                            voz                             600
# 97                            voz                             600
# 98                            anz                             681
# 99                            anz                             681
#
#    flight.codeshared.flight_iata flight.codeshared.flight_icao
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ..                           ...                           ...
# 95                         va600                        voz600
# 96                         va600                        voz600
# 97                         va600                        voz600
# 98                         nz681                        anz681
# 99                         nz681                        anz681
#
# [100 rows x 54 columns]

# %%
flights.describe
# Out:
# <bound method NDFrame.describe of    flight_date flight_status             departure.airport  \
# 0   2021-12-01        active             Kozhikode Airport
# 1   2021-12-01        active                      Shenzhen
# 2   2021-12-01        active      Townsville International
# 3   2021-12-01        active  Soekarno-Hatta International
# 4   2021-12-01        active                Port Macquarie
# ..         ...           ...                           ...
# 95  2021-12-01        active                        Mackay
# 96  2021-12-01        active                        Mackay
# 97  2021-12-01        active                        Mackay
# 98  2021-12-01        active      Wellington International
# 99  2021-12-01        active      Wellington International
#
#     departure.timezone departure.iata departure.icao departure.terminal  \
# 0         Asia/Kolkata            CCJ           VOCL               None
# 1        Asia/Shanghai            SZX           ZGSZ               None
# 2   Australia/Brisbane            TSV           YBTL               None
# 3         Asia/Jakarta            CGK           WIII                  2
# 4     Australia/Sydney            PQQ           YPMQ               None
# ..                 ...            ...            ...                ...
# 95  Australia/Brisbane            MKY           YBMK               None
# 96  Australia/Brisbane            MKY           YBMK               None
# 97  Australia/Brisbane            MKY           YBMK               None
# 98    Pacific/Auckland            WLG           NZWN               None
# 99    Pacific/Auckland            WLG           NZWN               None
#
#    departure.gate  departure.delay        departure.scheduled  ...  \
# 0            None              7.0  2021-12-01T00:35:00+00:00  ...
# 1            None             13.0  2021-12-01T03:25:00+00:00  ...
# 2               4             13.0  2021-12-01T06:00:00+00:00  ...
# 3             C22             16.0  2021-12-01T02:30:00+00:00  ...
# 4            None              2.0  2021-12-01T06:40:00+00:00  ...
# ..            ...              ...                        ...  ...
# 95              4              NaN  2021-12-01T06:30:00+00:00  ...
# 96              4              NaN  2021-12-01T06:30:00+00:00  ...
# 97              4              NaN  2021-12-01T06:30:00+00:00  ...
# 98             17             14.0  2021-12-01T08:50:00+00:00  ...
# 99             17             14.0  2021-12-01T08:50:00+00:00  ...
#
#    live.speed_vertical live.is_ground aircraft live  \
# 0                  0.0          False      NaN  NaN
# 1                  NaN            NaN      NaN  NaN
# 2                  NaN            NaN      NaN  NaN
# 3                  NaN            NaN      NaN  NaN
# 4                  NaN            NaN      NaN  NaN
# ..                 ...            ...      ...  ...
# 95                 NaN            NaN      NaN  NaN
# 96                 NaN            NaN      NaN  NaN
# 97                 NaN            NaN      NaN  NaN
# 98                 NaN            NaN      NaN  NaN
# 99                 NaN            NaN      NaN  NaN
#
#    flight.codeshared.airline_name flight.codeshared.airline_iata  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# ..                            ...                            ...
# 95               virgin australia                             va
# 96               virgin australia                             va
# 97               virgin australia                             va
# 98                air new zealand                             nz
# 99                air new zealand                             nz
#
#    flight.codeshared.airline_icao flight.codeshared.flight_number  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# ..                            ...                             ...
# 95                            voz                             600
# 96                            voz                             600
# 97                            voz                             600
# 98                            anz                             681
# 99                            anz                             681
#
#    flight.codeshared.flight_iata flight.codeshared.flight_icao
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ..                           ...                           ...
# 95                         va600                        voz600
# 96                         va600                        voz600
# 97                         va600                        voz600
# 98                         nz681                        anz681
# 99                         nz681                        anz681
#
# [100 rows x 54 columns]>
